# %%
import numpy as np
import pandas as pd
import os, re, math, platform
from pathlib import Path
import matplotlib.pyplot as plt
import json
import joblib
from scipy.stats import randint as sp_randint
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import matthews_corrcoef, confusion_matrix
from sklearn.metrics import precision_recall_curve, roc_curve, auc, fbeta_score
from imblearn.metrics import geometric_mean_score
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier 
from xgboost import plot_importance
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,ExtraTreesClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from Bio import SeqIO
from Bio.SeqUtils.ProtParam import ProteinAnalysis as PA
from modlamp.descriptors import PeptideDescriptor, GlobalDescriptor
from matplotlib import pyplot
from sklearn.metrics import matthews_corrcoef, confusion_matrix,precision_recall_curve, roc_curve, auc, fbeta_score,roc_auc_score
from fea_extract import read_fasta,insert_AAC,insert_DPC,insert_CKSAAGP,insert_CTD,insert_PAAC,insert_AAI,insert_GTPC,insert_QSO,insert_AAE,insert_PSAAC,insert_word2int,insert_ASDC
import warnings 
from tools import cv,evaluate
warnings.filterwarnings('ignore')

# %%
seed = 10
Path('./results/evalue/').mkdir(exist_ok=True,parents=True)
Path('./results/evalue_balance/').mkdir(exist_ok=True,parents=True)

# %%
GBDT = GradientBoostingClassifier(random_state=seed)
ET = ExtraTreesClassifier(random_state=seed)
SVM = SVC(random_state=seed,probability=True)
MLP = MLPClassifier(hidden_layer_sizes=32,learning_rate="adaptive",random_state=seed)
RF = RandomForestClassifier(random_state=seed)
XGBoost = XGBClassifier(random_state=seed)
LR  = LogisticRegression(random_state=seed)
AB = AdaBoostClassifier(random_state=seed)
clf_feature_order = {
    "AAC": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "PAAC": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "CKSAAGP": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
     "PSAAC": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "DPC": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "GTPC": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "QSO": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
     "AAE": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
     "AAI": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "ASDC": ["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "CTD" :["XGBoost","RF","ET","SVM","MLP","GBDT","AB"],
    "All_data" :["XGBoost","RF","ET","SVM","MLP","GBDT","AB"]
}

# %%
index = []
ALL_evals = pd.DataFrame()
for (n,m) in clf_feature_order.items():
    print('process_{}'.format(n))
    X = pd.read_csv('results/process_data/train_{}.csv'.format(n))
    feature = X.columns[2:]
    X_ = X[feature] .to_numpy()
    Y_ = pd.read_csv('data/train/y_train.csv').to_numpy()
    #encode and evaluate
    np.random.seed(1234)
    idx = np.random.permutation(len(X_))
    X_ = X_[idx]
    Y_ = Y_[idx]
    for i in m:
        model = eval(i)
        Evals = cv(model,X_,Y_)
        ALL_evals = pd.concat([ALL_evals,Evals],axis=1)
        index.append('{}_{}'.format(n,i))
ALL_evals.columns=index
# Out:
# process_AAC
# process_PAAC
# process_CKSAAGP
# process_PSAAC
# process_DPC
# process_GTPC
# process_QSO
# process_AAE
# process_AAI
# process_ASDC
# process_CTD
# process_All_data

# %%
#Cross validation test
def cv_test(model,df_X_train,df_y_train,df_X_test,df_y_test,n_folds=5):
    eval_dict = []
    kf = KFold(n_splits=5, shuffle=True, random_state=10)
    for train_index, test_index in kf.split(df_X_train, df_y_train):
        X_train_ = df_X_train[train_index]
        y_train_ = df_y_train[train_index]
        model.fit(X_train_,y_train_)
        eval_dictionary = evaluate(df_X_test,df_y_test,model)
        eval_dict = eval_dict+[eval_dictionary]
    evals = pd.DataFrame(eval_dict).mean()
    Evals = pd.DataFrame(evals)
    return Evals

# %%
index = []
ALL_evals_test = pd.DataFrame()
for (n,m) in clf_feature_order.items():
    print('process_{}'.format(n))
    X_train = pd.read_csv('results/process_data/train_{}.csv'.format(n))
    X_test = pd.read_csv('results/process_data/test_{}.csv'.format(n))
    feature = X_train.columns[2:]
    x_train = X_train[feature] .to_numpy()
    x_test = X_test[feature].to_numpy()
    y_train = pd.read_csv('data/train/y_train.csv').to_numpy()
    y_test = pd.read_csv('data/test/y_test.csv').to_numpy()
    
#     np.random.seed(1234)
#     idx_test = np.random.permutation(len(x_test))
#     idx_train = np.random.permutation(len(x_train))
#     x_test1 = x_test[idx_test]
#     y_test1 = y_test[idx_test]
#     x_train1 = x_train[idx_train]
#     y_train1 = y_train[idx_train]
    for i in m:
        eval_dict=[]
        model = eval(i)
        Evals = cv_test(model,x_train,y_train,x_test,y_test)
        ALL_evals_test = pd.concat([ALL_evals_test,Evals],axis=1)
        index.append('{}_{}'.format(n,i))
ALL_evals_test.columns=index
# Out:
# process_AAC
# process_PAAC
# process_CKSAAGP
# process_PSAAC
# process_DPC
# process_GTPC
# process_QSO
# process_AAE
# process_AAI
# process_ASDC
# process_CTD
# process_All_data

# %%
ALL_evals.to_csv("results/evalue/select_encodings_ML.csv")

# %%
ALL_evals_test.to_csv("results/evalue/select_encodings_ML_test.csv")

# %%
#!pip install shap
# Out:
# Requirement already satisfied: shap in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (0.42.1)
# Requirement already satisfied: slicer==0.0.7 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (0.0.7)
# Requirement already satisfied: scipy in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (1.7.3)
# Requirement already satisfied: pandas in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (1.3.5)
# Requirement already satisfied: tqdm>=4.27.0 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (4.66.1)
# Requirement already satisfied: cloudpickle in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (2.2.1)
# Requirement already satisfied: scikit-learn in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (1.0.2)
# Requirement already satisfied: numpy in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (1.21.5)
# Requirement already satisfied: numba in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from shap) (0.56.4)
# Requirement already satisfied: packaging>20.9 in /home/sadik/.local/lib/python3.7/site-packages (from shap) (23.0)
# Requirement already satisfied: setuptools in /home/sadik/.local/lib/python3.7/site-packages (from numba->shap) (67.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: importlib-metadata in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from numba->shap) (4.11.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/sadik/.local/lib/python3.7/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from pandas->shap) (2022.7)
# Requirement already satisfied: joblib>=0.11 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from scikit-learn->shap) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in /home/sadik/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from importlib-metadata->numba->shap) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/sadik/anaconda3/envs/reset/lib/python3.7/site-packages (from importlib-metadata->numba->shap) (3.11.0)
