# %%
import numpy as np
import pandas as pd
import os, re, math, platform
from pathlib import Path
import matplotlib.pyplot as plt
import json
import joblib
from scipy.stats import randint as sp_randint
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import matthews_corrcoef, confusion_matrix
from sklearn.metrics import precision_recall_curve, roc_curve, auc, fbeta_score
from imblearn.metrics import geometric_mean_score
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier 
from xgboost import plot_importance
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,ExtraTreesClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from Bio import SeqIO
from Bio.SeqUtils.ProtParam import ProteinAnalysis as PA
from modlamp.descriptors import PeptideDescriptor, GlobalDescriptor
from matplotlib import pyplot
from sklearn.metrics import matthews_corrcoef, confusion_matrix,precision_recall_curve, roc_curve, auc, fbeta_score,roc_auc_score
from fea_extract import read_fasta,insert_AAC,insert_DPC,insert_CKSAAGP,insert_CTD,insert_PAAC,insert_AAI,insert_GTPC,insert_QSO,insert_AAE,insert_PSAAC,insert_word2int,insert_ASDC
import warnings 
from collections import Counter
from tools import cv,evaluate, pro_data
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.combine import SMOTEENN
warnings.filterwarnings('ignore')
seed = 10

# %%
X_test_norm = pd.read_csv('data/test/X_test_norm.csv').to_numpy()
y_test_norm =pd.read_csv('data/test/y_test.csv').to_numpy()
X_train_resampled = pd.read_csv('data/train/X_train_resampled.csv').to_numpy()
y_train_resampled = pd.read_csv('data/train/y_train_resampled.csv').to_numpy()

# %%
#Boruta
from boruta import BorutaPy
np.random.seed(1234)
idx = np.random.permutation(len(X_train_resampled))
X_norm_train = X_train_resampled[idx]
y_norm_train = y_train_resampled[idx]
ET = ExtraTreesClassifier(random_state=10)
xgb = XGBClassifier(random_state = 10)
feat_selector = BorutaPy(xgb, n_estimators='auto', verbose=2, random_state=seed)

# %%
feat_selector.fit(X_norm_train,y_norm_train)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	1296
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	1296
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	1296
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	1296
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	1296
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	1296
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	1296
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	78
# Rejected: 	1218
# Iteration: 	9 / 100
# Confirmed: 	11
# Tentative: 	67
# Rejected: 	1218
# Iteration: 	10 / 100
# Confirmed: 	11
# Tentative: 	67
# Rejected: 	1218
# Iteration: 	11 / 100
# Confirmed: 	11
# Tentative: 	67
# Rejected: 	1218
# Iteration: 	12 / 100
# Confirmed: 	14
# Tentative: 	51
# Rejected: 	1231
# Iteration: 	13 / 100
# Confirmed: 	14
# Tentative: 	51
# Rejected: 	1231
# Iteration: 	14 / 100
# Confirmed: 	14
# Tentative: 	51
# Rejected: 	1231
# Iteration: 	15 / 100
# Confirmed: 	14
# Tentative: 	51
# Rejected: 	1231
# Iteration: 	16 / 100
# Confirmed: 	15
# Tentative: 	50
# Rejected: 	1231
# Iteration: 	17 / 100
# Confirmed: 	15
# Tentative: 	48
# Rejected: 	1233
# Iteration: 	18 / 100
# Confirmed: 	15
# Tentative: 	48
# Rejected: 	1233
# Iteration: 	19 / 100
# Confirmed: 	18
# Tentative: 	41
# Rejected: 	1237
# Iteration: 	20 / 100
# Confirmed: 	18
# Tentative: 	41
# Rejected: 	1237
# Iteration: 	21 / 100
# Confirmed: 	18
# Tentative: 	41
# Rejected: 	1237
# Iteration: 	22 / 100
# Confirmed: 	21
# Tentative: 	38
# Rejected: 	1237
# Iteration: 	23 / 100
# Confirmed: 	21
# Tentative: 	38
# Rejected: 	1237
# Iteration: 	24 / 100
# Confirmed: 	21
# Tentative: 	37
# Rejected: 	1238
# Iteration: 	25 / 100
# Confirmed: 	21
# Tentative: 	37
# Rejected: 	1238
# Iteration: 	26 / 100
# Confirmed: 	22
# Tentative: 	36
# Rejected: 	1238
# Iteration: 	27 / 100
# Confirmed: 	22
# Tentative: 	36
# Rejected: 	1238
# Iteration: 	28 / 100
# Confirmed: 	22
# Tentative: 	36
# Rejected: 	1238
# Iteration: 	29 / 100
# Confirmed: 	27
# Tentative: 	30
# Rejected: 	1239
# Iteration: 	30 / 100
# Confirmed: 	27
# Tentative: 	30
# Rejected: 	1239
# Iteration: 	31 / 100
# Confirmed: 	27
# Tentative: 	30
# Rejected: 	1239
# Iteration: 	32 / 100
# Confirmed: 	30
# Tentative: 	23
# Rejected: 	1243
# Iteration: 	33 / 100
# Confirmed: 	30
# Tentative: 	23
# Rejected: 	1243
# Iteration: 	34 / 100
# Confirmed: 	30
# Tentative: 	23
# Rejected: 	1243
# Iteration: 	35 / 100
# Confirmed: 	30
# Tentative: 	23
# Rejected: 	1243
# Iteration: 	36 / 100
# Confirmed: 	30
# Tentative: 	23
# Rejected: 	1243
# Iteration: 	37 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	38 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	39 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	40 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	41 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	42 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	43 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	44 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	45 / 100
# Confirmed: 	31
# Tentative: 	22
# Rejected: 	1243
# Iteration: 	46 / 100
# Confirmed: 	31
# Tentative: 	21
# Rejected: 	1244
# Iteration: 	47 / 100
# Confirmed: 	31
# Tentative: 	21
# Rejected: 	1244
# Iteration: 	48 / 100
# Confirmed: 	31
# Tentative: 	21
# Rejected: 	1244
# Iteration: 	49 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	50 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	51 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	52 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	53 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	54 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	55 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	56 / 100
# Confirmed: 	32
# Tentative: 	19
# Rejected: 	1245
# Iteration: 	57 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	58 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	59 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	60 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	61 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	62 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	63 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	64 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	65 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	66 / 100
# Confirmed: 	33
# Tentative: 	18
# Rejected: 	1245
# Iteration: 	67 / 100
# Confirmed: 	34
# Tentative: 	17
# Rejected: 	1245
# Iteration: 	68 / 100
# Confirmed: 	34
# Tentative: 	17
# Rejected: 	1245
# Iteration: 	69 / 100
# Confirmed: 	34
# Tentative: 	17
# Rejected: 	1245
# Iteration: 	70 / 100
# Confirmed: 	34
# Tentative: 	17
# Rejected: 	1245
# Iteration: 	71 / 100
# Confirmed: 	34
# Tentative: 	17
# Rejected: 	1245
# Iteration: 	72 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	73 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	74 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	75 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	76 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	77 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	78 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	79 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	80 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	81 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	82 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	83 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	84 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	85 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	86 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	87 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	88 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	89 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	90 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	91 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	92 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	93 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	94 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	95 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	96 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	97 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	98 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
# Iteration: 	99 / 100
# Confirmed: 	34
# Tentative: 	16
# Rejected: 	1246
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	34
# Tentative: 	10
# Rejected: 	1246
# BorutaPy(estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                  callbacks=None, colsample_bylevel=1,
#                                  colsample_bynode=1, colsample_bytree=1,
#                                  early_stopping_rounds=None,
#                                  enable_categorical=False, eval_metric=None,
#                                  gamma=0, gpu_id=-1, grow_policy='depthwise',
#                                  importance_type=None,
#                                  interaction_constraints='',
#                                  learning_rate=0.300000012, max_bin=256,
#                                  max_cat_to_onehot=4, max_delta_step=0,
#                                  max_depth=6, max_leaves=0, min_child_weight=1,
#                                  missing=nan, monotone_constraints='()',
#                                  n_estimators=166, n_jobs=0,
#                                  num_parallel_tree=1, predictor='auto',
#                                  random_state=1767254652, reg_alpha=0,
#                                  reg_lambda=1, ...),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x7F77AE9807C0, verbose=2)

# %%
index_ = feat_selector.ranking_

# %%
import pandas as pd
index = pd.DataFrame(index_[:34])
index.to_csv('Boruta_index.csv')

# %%
PAAC=23
AAC=20
CKSAAGP=75
CTD=147
DPC=400
GTPC=125
QSO=46
AAE=60
ASDC=400
PAAC_N=0
AAC_N=0
CKSAAGP_N=0
CTD_N=0
DPC_N=0
GTPC_N=0
QSO_N=0
AAE_N=0
ASDC_N=0

# %%
NUM=[]
NUM1 = []
for i in index_[:34]:
    if 0<= int(i) <23:
        PAAC_N += 1
    elif 23<= int(i) <43:
        AAC_N += 1
    elif 43<= int(i) <118:
        CKSAAGP_N += 1
    elif 118<= int(i) <265:
        CTD_N += 1
    elif 265<= int(i) <665:
        DPC_N += 1
    elif 665<= int(i) <790:
        GTPC_N += 1
    elif 790<= int(i) <836:
        QSO_N += 1
    elif 836<= int(i) <896:
        AAE_N += 1
    elif 896<= int(i) <1296:
        ASDC_N += 1
NUM.append(PAAC_N/23)
NUM.append(AAC_N/20)
NUM.append(CKSAAGP_N/75)
NUM.append(CTD_N/147)
NUM.append(DPC_N/400)
NUM.append(GTPC_N/125)
NUM.append(QSO_N/46)
NUM.append(AAE_N/60)
NUM.append(ASDC_N/400)
NUM1.append(PAAC_N)
NUM1.append(AAC_N)
NUM1.append(CKSAAGP_N)
NUM1.append(CTD_N)
NUM1.append(DPC_N)
NUM1.append(GTPC_N)
NUM1.append(QSO_N)
NUM1.append(AAE_N)
NUM1.append(ASDC_N)

# %%
# Define the ranges and corresponding variables
ranges = [(0, 23, 'PAAC_N'), (23, 43, 'AAC_N'), (43, 118, 'CKSAAGP_N'), 
          (118, 265, 'CTD_N'), (265, 665, 'DPC_N'), (665, 790, 'GTPC_N'), 
          (790, 836, 'QSO_N'), (836, 896, 'AAE_N'), (896, 1296, 'ASDC_N')]

# Initialize the variables
variables = {name: 0 for _, _, name in ranges}

# Iterate over the indices and update the variables
for i in index_[:34]:
    i = int(i)
    for low, high, name in ranges:
        if low <= i < high:
            variables[name] += 1
            break

# Calculate the NUM and NUM1 lists
NUM = [variables[name]/(high-low) for low, high, name in ranges]
NUM1 = [variables[name] for _, _, name in ranges]

# %%
NUm = np.array(NUM)*(34/1296)

# %%
names = ['PAAC','AAC','CKSAAGP','CTD','DPC','GTPC','QSO','AAE','ASDC']

# %%
sns.set()
plt.figure(figsize=(10,8))
plt.grid(False)
plt.barh(names,NUm,label='Boruta')
plt.legend(loc='upper right')
plt.xlim(0.0,0.5)
# Out:
# (0.0, 0.5)

# %%
plt.figure(figsize=(20, 9), dpi=100)

# 3）绘制饼图
plt.pie(NUm, labels=names, colors=['b','r','g','y','c','m','y','k'])

# # 显示图例
# plt.legend(loc='best')

# # 添加标题
# plt.title("o1PO )oineH. 93viuo.uod")

# 4）显示图像
plt.show()

# %%
X_A = pd.read_csv('data/train/X_train_resampled_all.csv').to_numpy()

# %%
X_norm_filtered_train = feat_selector.transform(X_A)
X_train_boruta = pd.DataFrame(X_norm_filtered_train)
X_train_boruta.to_csv('Feature_different/X_train_Boruta_A.csv',index = False)

# %%
X_norm_filtered_train = feat_selector.transform(X_train_resampled)
X_train_boruta = pd.DataFrame(X_norm_filtered_train)
X_train_boruta.to_csv('Feature_different/X_train_Boruta.csv',index = False)
X_norm_filtered_test = feat_selector.transform(X_test_norm)
X_test_boruta = pd.DataFrame(X_norm_filtered_test)
X_test_boruta.to_csv('Feature_different/X_test_Boruta.csv',index = False)

# %%
feat_selector.support_
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
num_d = np.zeros([1296,1])
for i in index_[:34]:
    num_d[int(i)]=1

# %%
num_D = pd.DataFrame(num_d)
num_D.to_csv('Boruta.csv',index=False)

# %%
MI = pd.DataFrame(index_)
MI.to_csv('data/Boruta.csv',index=False)
